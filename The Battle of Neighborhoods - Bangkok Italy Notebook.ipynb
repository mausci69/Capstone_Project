# %% [markdown]
# # THE BATTLE OF NEIGHBORHOODS

# %% [markdown]
# ## Bangkok and its districts

# %%
# importing libraries
import pandas as pd
import folium
import requests

# %%
# Scraping Wikipedia to see the districts of Bangkok
bkk_dist = pd.read_html('https://en.wikipedia.org/wiki/List_of_districts_of_Bangkok')
bkk_dist = bkk_dist[0]

# Adding the missing coordinates
# Bang Bon coordinates
bkk_dist.iloc[0,-2] = 13.6592
bkk_dist.iloc[0,-1] = 100.3991

# Khan Na Yao coordinates
bkk_dist.iloc[19,-2] = 13.8271
bkk_dist.iloc[19,-1] = 100.6743

# Thawi Watthana coordinates
bkk_dist.iloc[44,-2] = 13.7878
bkk_dist.iloc[44,-1] = 100.3638

# Thung Khru coordinates
bkk_dist.iloc[46,-2] = 13.6472
bkk_dist.iloc[46,-1] = 100.4958

# Wang Thonglang coordinates
bkk_dist.iloc[47,-2] = 13.7864
bkk_dist.iloc[47,-1] = 100.6087

bkk_dist
# Out:
#           District(Khet)  Code               Thai  Population  \
# 0               Bang Bon    50             บางบอน      105161
# 1              Bang Kapi     6            บางกะปิ      148465
# 2              Bang Khae    40              บางแค      191781
# 3              Bang Khen     5             บางเขน      189539
# 4          Bang Kho Laem    31          บางคอแหลม       94956
# 5        Bang Khun Thian    21        บางขุนเทียน      165491
# 6                Bang Na    47              บางนา       95912
# 7             Bang Phlat    25            บางพลัด       99273
# 8               Bang Rak     4             บางรัก       45875
# 9               Bang Sue    29            บางซื่อ      132234
# 10           Bangkok Noi    20         บางกอกน้อย      117793
# 11           Bangkok Yai    16         บางกอกใหญ่       72321
# 12             Bueng Kum    27            บึงกุ่ม      145830
# 13             Chatuchak    30            จตุจักร      160906
# 14            Chom Thong    35             จอมทอง      158005
# 15             Din Daeng    26             ดินแดง      130220
# 16            Don Mueang    36           ดอนเมือง      166261
# 17                 Dusit     2              ดุสิต      107655
# 18           Huai Khwang    17           ห้วยขวาง       78175
# 19           Khan Na Yao    43           คันนายาว       88678
# 20         Khlong Sam Wa    46          คลองสามวา      169489
# 21            Khlong San    18            คลองสาน       76446
# 22           Khlong Toei    33            คลองเตย      109041
# 23                Lak Si    41            หลักสี่      109770
# 24           Lat Krabang    11          ลาดกระบัง      163175
# 25             Lat Phrao    38           ลาดพร้าว      122182
# 26              Min Buri    10            มีนบุรี      137251
# 27             Nong Chok     3            หนองจอก      157138
# 28            Nong Khaem    23            หนองแขม      150218
# 29            Pathum Wan     7            ปทุมวัน       53263
# 30         Phasi Charoen    22          ภาษีเจริญ      129827
# 31            Phaya Thai    14              พญาไท       72952
# 32          Phra Khanong     9            พระโขนง       93482
# 33           Phra Nakhon     1             พระนคร       57876
# 34  Pom Prap Sattru Phai     8  ป้อมปราบศัตรูพ่าย       51006
# 35                Prawet    32             ประเวศ      160671
# 36            Rat Burana    24        ราษฎร์บูรณะ       86695
# 37           Ratchathewi    37            ราชเทวี       73035
# 38               Sai Mai    42             สายไหม      188123
# 39        Samphanthawong    13        สัมพันธวงศ์       27452
# 40           Saphan Sung    44           สะพานสูง       89825
# 41                Sathon    28               สาทร       84916
# 42            Suan Luang    34            สวนหลวง      115658
# 43           Taling Chan    19           ตลิ่งชัน      106604
# 44        Thawi Watthana    48           ทวีวัฒนา       76351
# 45             Thon Buri    15             ธนบุรี      119708
# 46            Thung Khru    49            ทุ่งครุ      116473
# 47        Wang Thonglang    45         วังทองหลาง      114768
# 48              Watthana    39              วัฒนา       81623
# 49              Yan Nawa    12            ยานนาวา       81521
#
#     No. ofSubdistricts(Khwaeng)   Latitude   Longitude
# 0                             4  13.659200  100.399100
# 1                             2  13.765833  100.647778
# 2                             4  13.696111  100.409444
# 3                             2  13.873889  100.596389
# 4                             3  13.693333  100.502500
# 5                             2  13.660833  100.435833
# 6                             2  13.680081  100.591800
# 7                             4  13.793889  100.505000
# 8                             5  13.730833  100.524167
# 9                             2  13.809722  100.537222
# 10                            5  13.770867  100.467933
# 11                            2  13.722778  100.476389
# 12                            3  13.785278  100.669167
# 13                            5  13.828611  100.559722
# 14                            4  13.677222  100.484722
# 15                            2  13.769722  100.552778
# 16                            3  13.913611  100.589722
# 17                            5  13.776944  100.520556
# 18                            3  13.776667  100.579444
# 19                            2  13.827100  100.674300
# 20                            5  13.859722  100.704167
# 21                            4  13.730278  100.509722
# 22                            3  13.708056  100.583889
# 23                            2  13.887500  100.578889
# 24                            6  13.722317  100.759669
# 25                            2  13.803611  100.607500
# 26                            2  13.813889  100.748056
# 27                            8  13.855556  100.862500
# 28                            2  13.704722  100.348889
# 29                            4  13.744942  100.522200
# 30                            7  13.714722  100.437222
# 31                            2  13.780000  100.542778
# 32                            2  13.702222  100.601667
# 33                           12  13.764444  100.499167
# 34                            5  13.758056  100.513056
# 35                            3  13.716944  100.694444
# 36                            2  13.682222  100.505556
# 37                            4  13.758889  100.534444
# 38                            3  13.919167  100.645833
# 39                            3  13.731389  100.514167
# 40                            3  13.770000  100.684722
# 41                            3  13.708056  100.526389
# 42                            3  13.730278  100.651389
# 43                            6  13.776944  100.456667
# 44                            2  13.787800  100.363800
# 45                            7  13.725000  100.485833
# 46                            2  13.647200  100.495800
# 47                            4  13.786400  100.608700
# 48                            3  13.742222  100.585833
# 49                            2  13.696944  100.543056

# %%
# Showing a map of Bangkok with its 50 districts, just to check that everything works okay
latitude = 13.7563
longitude = 100.5018
map_bangkok = folium.Map(location=[latitude, longitude], zoom_start=11)

# extracting the two districts of the two BTS Stops to show them with a different colour
bkk_sel_dist = []
bkk_sel_dist.append([bkk_dist.iloc[22,0], bkk_dist.iloc[22,-2], bkk_dist.iloc[22,-1]])
bkk_sel_dist.append([bkk_dist.iloc[31,0], bkk_dist.iloc[31,-2], bkk_dist.iloc[31,-1]])
bkk_dist.drop([22,31], inplace=True)     

for i in range(len(bkk_dist)):
    folium.Marker(location=[bkk_dist.iloc[i,-2], bkk_dist.iloc[i,-1]], popup=bkk_dist.iloc[i,0], icon=folium.Icon(color='blue', icon='building', prefix='fa')).add_to(map_bangkok)
for i in range(len(bkk_sel_dist)):
    folium.Marker(location=[bkk_sel_dist[i][-2], bkk_sel_dist[i][-1]], popup=bkk_sel_dist[i][0], icon=folium.Icon(color='red', icon='building', prefix='fa')).add_to(map_bangkok)
map_bangkok
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Foursquare 
CLIENT_ID = 'BTLFWZ1PUF4GT0J3F5H5KBNXS345DZDQRJ2CCXX0I251AUJH' # your Foursquare ID
CLIENT_SECRET = '1W0MVZFCSKGFFCUA52GZ4OI3G0U2ZEY5TVUZYCZHJRYM3RJ2' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BTLFWZ1PUF4GT0J3F5H5KBNXS345DZDQRJ2CCXX0I251AUJH
# CLIENT_SECRET:1W0MVZFCSKGFFCUA52GZ4OI3G0U2ZEY5TVUZYCZHJRYM3RJ2

# %% [markdown]
# ## <u>Ari BTS Station</u>

# %%
# create map of Bangkok around the Ari BTS Station using its latitude and longitude
latitude = 13.7796
longitude = 100.5446
map_bangkok_ari = folium.Map(location=[latitude, longitude], zoom_start=17)

folium.Marker(location=[latitude, longitude], icon=folium.Icon(color='orange', icon='train', prefix='fa')).add_to(map_bangkok_ari)
map_bangkok_ari
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Searching for pizza places at not more than 500 mts from the Ari BTS stop
LL = str(latitude) + ', ' + str(longitude)
RADIUS =500
CATEGORY_ID = '4bf58dd8d48988d1ca941735' # PIZZA PLACES CATEGORY ID
LIMIT = 50 # MAXIMUM VALUE
url = 'https://api.foursquare.com/v2/venues/search?ll={}&radius={}&categoryId={}&client_id={}&client_secret={}&v={}&limit={}'.format(
    LL,
    RADIUS,
    CATEGORY_ID,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    LIMIT
)

url
# Out:
# 'https://api.foursquare.com/v2/venues/search?ll=13.7796, 100.5446&radius=500&categoryId=4bf58dd8d48988d1ca941735&client_id=BTLFWZ1PUF4GT0J3F5H5KBNXS345DZDQRJ2CCXX0I251AUJH&client_secret=1W0MVZFCSKGFFCUA52GZ4OI3G0U2ZEY5TVUZYCZHJRYM3RJ2&v=20180605&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dfa482f1d67cb001bfe304f'},
#  'response': {'venues': [{'id': '4e62f98162e13e3bcee4427d',
#     'name': 'The Pizza Company (เดอะ พิซซ่า คอมปะนี)',
#     'location': {'address': 'Phahon Yothin Rd.',
#      'lat': 13.781437766403533,
#      'lng': 100.54528204454901,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.781437766403533,
#        'lng': 100.54528204454901}],
#      'distance': 217,
#      'cc': 'TH',
#      'city': 'พญาไท',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Phahon Yothin Rd.',
#       'พญาไท',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683635',
#     'hasPerk': False},
#    {'id': '4b4dc2e9f964a52011d726e3',
#     'name': 'Basilico (บาซิลิโก)',
#     'location': {'address': '34 Phahon Yothin 7',
#      'crossStreet': 'at Baan Yoswadi',
#      'lat': 13.78207301683207,
#      'lng': 100.54356411905705,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.78207301683207,
#        'lng': 100.54356411905705}],
#      'distance': 297,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'city': 'พญาไท',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['34 Phahon Yothin 7 (at Baan Yoswadi)',
#       'พญาไท',
#       'กรุงเทพมหานคร 10400',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683635',
#     'hasPerk': False},
#    {'id': '4bfcb4f2bf6576b0584bacb8',
#     'name': 'Italian Job (อิตาเลียน จ็อบ)',
#     'location': {'address': 'La Villa',
#      'crossStreet': '#310',
#      'lat': 13.780012590635176,
#      'lng': 100.54494444212,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.780012590635176,
#        'lng': 100.54494444212}],
#      'distance': 59,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'city': 'พญาไท',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['La Villa (#310)',
#       'พญาไท',
#       'กรุงเทพมหานคร 10400',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683635',
#     'hasPerk': False},
#    {'id': '4e8866d46c25eede899f35d8',
#     'name': 'The Pizza Companny',
#     'location': {'address': 'ซ.พหลโยธิน2',
#      'lat': 13.776339504805465,
#      'lng': 100.54333715884258,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.776339504805465,
#        'lng': 100.54333715884258}],
#      'distance': 387,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ซ.พหลโยธิน2', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683635',
#     'hasPerk': False},
#    {'id': '4c834319d4e23704edb96f88',
#     'name': 'The Pizza Company @ soi phahonyothin4th',
#     'location': {'address': 'ปากซอยพหลโยธิน4',
#      'lat': 13.777538,
#      'lng': 100.54621,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.777538,
#        'lng': 100.54621}],
#      'distance': 288,
#      'cc': 'TH',
#      'city': 'สามเสนใน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ปากซอยพหลโยธิน4',
#       'สามเสนใน',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683635',
#     'hasPerk': False},
#    {'id': '4d11dcbd85db5481e63fc321',
#     'name': 'Raan Labudon',
#     'location': {'lat': 13.780276,
#      'lng': 100.543911,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.780276,
#        'lng': 100.543911}],
#      'distance': 105,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683635',
#     'hasPerk': False}],
#   'confident': False}}

# %%
# importing library to normalize the json data
from pandas.io.json import json_normalize

venues = results['response']['venues']
    
bkk_pizza_ari = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['id',
                    'name', 
                    'location.lat', 
                    'location.lng',
                    'location.address'
                   ]
bkk_pizza_ari = bkk_pizza_ari.loc[:, filtered_columns]

# clean columns
bkk_pizza_ari.columns = [col.split(".")[-1] for col in bkk_pizza_ari.columns]

bkk_pizza_ari
# Out:
#                          id                                     name  \
# 0  4e62f98162e13e3bcee4427d  The Pizza Company (เดอะ พิซซ่า คอมปะนี)
# 1  4b4dc2e9f964a52011d726e3                      Basilico (บาซิลิโก)
# 2  4bfcb4f2bf6576b0584bacb8             Italian Job (อิตาเลียน จ็อบ)
# 3  4e8866d46c25eede899f35d8                       The Pizza Companny
# 4  4c834319d4e23704edb96f88  The Pizza Company @ soi phahonyothin4th
# 5  4d11dcbd85db5481e63fc321                             Raan Labudon
#
#          lat         lng             address
# 0  13.781438  100.545282   Phahon Yothin Rd.
# 1  13.782073  100.543564  34 Phahon Yothin 7
# 2  13.780013  100.544944            La Villa
# 3  13.776340  100.543337         ซ.พหลโยธิน2
# 4  13.777538  100.546210     ปากซอยพหลโยธิน4
# 5  13.780276  100.543911                 NaN

# %%
# Pizza Company is definitely not an italian place, as Raan Labudon
# Results order could change, so we use their names to cancel them
row_to_del = []
for i in range(len(bkk_pizza_ari)):
    if (bkk_pizza_ari.iloc[i,1].find('Pizza Compa') > -1):
        row_to_del.append(i)
    elif (bkk_pizza_ari.iloc[i,1].find('Raan Labudon') > -1):
        row_to_del.append(i)
bkk_pizza_ari = bkk_pizza_ari.drop(row_to_del, axis=0).reset_index().drop('index', axis=1)
bkk_pizza_ari
# Out:
#                          id                          name        lat  \
# 0  4b4dc2e9f964a52011d726e3           Basilico (บาซิลิโก)  13.782073
# 1  4bfcb4f2bf6576b0584bacb8  Italian Job (อิตาเลียน จ็อบ)  13.780013
#
#           lng             address
# 0  100.543564  34 Phahon Yothin 7
# 1  100.544944            La Villa

# %%
# importing library
import json

# checking the rating of the first restaurant in our list
bkk_pizza_ari_plus = pd.DataFrame(index=[0,1], columns=['price', 'likes', 'rating'])
url = 'https://api.foursquare.com/v2/venues/'
for i in range(len(bkk_pizza_ari)):
    VENUE_ID = bkk_pizza_ari.iloc[i,0]
    params = dict(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        v=VERSION
    )
    results = requests.get(url=url+VENUE_ID, params=params)
    data = json.loads(results.text)
    try:
        bkk_pizza_ari_plus.iloc[i,0] = data['response']['venue']['price']['message']
    except:
        bkk_pizza_ari_plus.iloc[i,0] = "no price"
    try:
        bkk_pizza_ari_plus.iloc[i,1] = data['response']['venue']['likes']['count']
    except:
        bkk_pizza_ari_plus.iloc[i,1] = "no likes"
    try:
        bkk_pizza_ari_plus.iloc[i,2] = data['response']['venue']['rating']
    except:
        bkk_pizza_ari_plus.iloc[i,2] = "no rating"

# %%
bkk_pizza_ari = pd.concat([bkk_pizza_ari, bkk_pizza_ari_plus], axis=1)
bkk_pizza_ari
# Out:
#                          id                          name        lat  \
# 0  4b4dc2e9f964a52011d726e3           Basilico (บาซิลิโก)  13.782073
# 1  4bfcb4f2bf6576b0584bacb8  Italian Job (อิตาเลียน จ็อบ)  13.780013
#
#           lng             address      price likes rating
# 0  100.543564  34 Phahon Yothin 7  Expensive    27    7.2
# 1  100.544944            La Villa  Expensive    10    5.5

# %%
# removing every pizza place with a rating inferior to 6
for i in range(len(bkk_pizza_ari)):
    if bkk_pizza_ari.iloc[i, -1] < 6:
        bkk_pizza_ari.drop(i, axis=0, inplace=True)
bkk_pizza_ari
# Out:
#                          id                 name        lat         lng  \
# 0  4b4dc2e9f964a52011d726e3  Basilico (บาซิลิโก)  13.782073  100.543564
#
#               address      price likes rating
# 0  34 Phahon Yothin 7  Expensive    27    7.2

# %%
# adding markers to the Bangok map around the Ari Station
for lat, lng, name, address in zip(bkk_pizza_ari['lat'], bkk_pizza_ari['lng'], bkk_pizza_ari['name'], bkk_pizza_ari['address']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#ff0000',
        fill=True,
        fill_color='#f00f00',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bangkok_ari)

# %% [markdown]
# ### GELATO

# %%
# Searching for ice-cream shops, with the word 'gelato' in their name
# at not more than 500 mts from the Ari BTS stop
CATEGORY_ID = '4bf58dd8d48988d1c9941735' # ICE CREAM SHOP CATEGORY ID
QUERY = 'gelato'
url = 'https://api.foursquare.com/v2/venues/search?ll={}&query={}&radius={}&categoryId={}&client_id={}&client_secret={}&v={}&limit={}'.format(
    LL,
    QUERY,
    RADIUS,
    CATEGORY_ID,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?ll=13.7796, 100.5446&query=gelato&radius=500&categoryId=4bf58dd8d48988d1c9941735&client_id=BTLFWZ1PUF4GT0J3F5H5KBNXS345DZDQRJ2CCXX0I251AUJH&client_secret=1W0MVZFCSKGFFCUA52GZ4OI3G0U2ZEY5TVUZYCZHJRYM3RJ2&v=20180605&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dfa48770be7b43a1202e174'},
#  'response': {'venues': [{'id': '507677d6e4b051090624fda2',
#     'name': 'Gelato Villa Aree',
#     'location': {'address': 'La Villa Aree',
#      'lat': 13.781373125765265,
#      'lng': 100.54592485480843,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.781373125765265,
#        'lng': 100.54592485480843}],
#      'distance': 243,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['La Villa Aree',
#       'กรุงเทพมหานคร 10400',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683640',
#     'hasPerk': False},
#    {'id': '55ea7d5c498ee151a6e81ab9',
#     'name': "D'Viva Gelato (เดอะ-วีว่า เจลาโต้)",
#     'location': {'address': 'ซ.อารีย์ 3',
#      'lat': 13.781634847841241,
#      'lng': 100.54269986061763,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.781634847841241,
#        'lng': 100.54269986061763}],
#      'distance': 305,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ซ.อารีย์ 3',
#       'พญาไท',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683640',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
    
bkk_gelato_ari = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['id',
                    'name', 
                    'location.lat', 
                    'location.lng',
                    'location.address'
                   ]
bkk_gelato_ari = bkk_gelato_ari.loc[:, filtered_columns]

# clean columns
bkk_gelato_ari.columns = [col.split(".")[-1] for col in bkk_gelato_ari.columns]

bkk_gelato_ari
# Out:
#                          id                                name        lat  \
# 0  507677d6e4b051090624fda2                   Gelato Villa Aree  13.781373
# 1  55ea7d5c498ee151a6e81ab9  D'Viva Gelato (เดอะ-วีว่า เจลาโต้)  13.781635
#
#           lng        address
# 0  100.545925  La Villa Aree
# 1  100.542700     ซ.อารีย์ 3

# %% [markdown]
# We keep them both

# %%
# checking rating, likes and price
bkk_gelato_ari_plus = pd.DataFrame(index=[0,1], columns=['price', 'likes', 'rating'])
url = 'https://api.foursquare.com/v2/venues/'
for i in range(len(bkk_gelato_ari)):
    VENUE_ID = bkk_gelato_ari.iloc[i,0]
    params = dict(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        v=VERSION
    )
    results = requests.get(url=url+VENUE_ID, params=params)
    data = json.loads(results.text)
    try:
        bkk_gelato_ari_plus.iloc[i,0] = data['response']['venue']['price']['message']
    except:
        bkk_gelato_ari_plus.iloc[i,0] = "no price"
    try:
        bkk_gelato_ari_plus.iloc[i,1] = data['response']['venue']['likes']['count']
    except:
        bkk_gelato_ari_plus.iloc[i,1] = "no likes"
    try:
        bkk_gelato_ari_plus.iloc[i,2] = data['response']['venue']['rating']
    except:
        bkk_gelato_ari_plus.iloc[i,2] = "no rating"

# %%
bkk_gelato_ari = pd.concat([bkk_gelato_ari, bkk_gelato_ari_plus], axis=1)
bkk_gelato_ari
# Out:
#                          id                                name        lat  \
# 0  507677d6e4b051090624fda2                   Gelato Villa Aree  13.781373
# 1  55ea7d5c498ee151a6e81ab9  D'Viva Gelato (เดอะ-วีว่า เจลาโต้)  13.781635
#
#           lng        address     price likes     rating
# 0  100.545925  La Villa Aree  Moderate     0  no rating
# 1  100.542700     ซ.อารีย์ 3  Moderate     3  no rating

# %% [markdown]
# We keep both of them

# %%
# add markers to map
for lat, lng, name, address in zip(bkk_gelato_ari['lat'], bkk_gelato_ari['lng'], bkk_gelato_ari['name'], bkk_gelato_ari['address']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#0080ff',
        fill=True,
        fill_color='#0080ff',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bangkok_ari)

# %% [markdown]
# ###  ESPRESSO

# %%
# Searching for coffee shops, with the word espresso in their name,
# at not more than 500 mts from the Ari BTS stop
CATEGORY_ID = '4bf58dd8d48988d1e0931735' # COFFEE SHOP CATEGORY ID
QUERY = 'espresso'
url = 'https://api.foursquare.com/v2/venues/search?ll={}&query={}&radius={}&categoryId={}&client_id={}&client_secret={}&v={}&limit={}'.format(
    LL,
    QUERY,
    RADIUS,
    CATEGORY_ID,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?ll=13.7796, 100.5446&query=espresso&radius=500&categoryId=4bf58dd8d48988d1e0931735&client_id=BTLFWZ1PUF4GT0J3F5H5KBNXS345DZDQRJ2CCXX0I251AUJH&client_secret=1W0MVZFCSKGFFCUA52GZ4OI3G0U2ZEY5TVUZYCZHJRYM3RJ2&v=20180605&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dfa48a3df2774001b3d0f1e'},
#  'response': {'venues': [{'id': '4f2cf81ce4b006ef98a049e3',
#     'name': 'The Espresso Bar (ดิ เอสเพรสโซ่ บาร์)',
#     'location': {'address': '19/3 Soi Ari 4 (Nua)',
#      'crossStreet': 'Phahon Yothin 7',
#      'lat': 13.783804047183525,
#      'lng': 100.54354043593045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.783804047183525,
#        'lng': 100.54354043593045}],
#      'distance': 481,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'city': 'พญาไท',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['19/3 Soi Ari 4 (Nua) (Phahon Yothin 7)',
#       'พญาไท',
#       'กรุงเทพมหานคร 10400',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683642',
#     'hasPerk': False},
#    {'id': '503c5a41e4b0f8bcbe90eb6c',
#     'name': 'Bangkok Espresso Bar',
#     'location': {'address': 'Phahon Yothin Rd',
#      'crossStreet': 'near Piyawan Tower & BTS Ari',
#      'lat': 13.780211566153698,
#      'lng': 100.5442924055835,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.780211566153698,
#        'lng': 100.5442924055835}],
#      'distance': 75,
#      'cc': 'TH',
#      'neighborhood': 'Ari',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Phahon Yothin Rd (near Piyawan Tower & BTS Ari)',
#       'พญาไท',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683642',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
    
bkk_espresso_ari = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['id',
                    'name', 
                    'location.lat', 
                    'location.lng',
                    'location.address'
                   ]
bkk_espresso_ari = bkk_espresso_ari.loc[:, filtered_columns]

# clean columns
bkk_espresso_ari.columns = [col.split(".")[-1] for col in bkk_espresso_ari.columns]

bkk_espresso_ari
# Out:
#                          id                                   name        lat  \
# 0  4f2cf81ce4b006ef98a049e3  The Espresso Bar (ดิ เอสเพรสโซ่ บาร์)  13.783804
# 1  503c5a41e4b0f8bcbe90eb6c                   Bangkok Espresso Bar  13.780212
#
#           lng               address
# 0  100.543540  19/3 Soi Ari 4 (Nua)
# 1  100.544292      Phahon Yothin Rd

# %%
# checking the rating of the first espresso place in our list
bkk_espresso_ari_plus = pd.DataFrame(index=[0,1], columns=['price', 'likes', 'rating'])
url = 'https://api.foursquare.com/v2/venues/'
for i in range(len(bkk_espresso_ari)):
    VENUE_ID = bkk_espresso_ari.iloc[i,0]
    params = dict(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        v=VERSION
    )
    results = requests.get(url=url+VENUE_ID, params=params)
    data = json.loads(results.text)
    try:
        bkk_espresso_ari_plus.iloc[i,0] = data['response']['venue']['price']['message']
    except:
        bkk_espresso_ari_plus.iloc[i,0] = "no price"
    try:
        bkk_espresso_ari_plus.iloc[i,1] = data['response']['venue']['likes']['count']
    except:
        bkk_espresso_ari_plus.iloc[i,1] = "no likes"
    try:
        bkk_espresso_ari_plus.iloc[i,2] = data['response']['venue']['rating']
    except:
        bkk_espresso_ari_plus.iloc[i,2] = "no rating"
bkk_espresso_ari_plus
# Out:
#    price likes     rating
# 0  Cheap     3  no rating
# 1  Cheap    23        7.4

# %%
bkk_espresso_ari = pd.concat([bkk_espresso_ari, bkk_espresso_ari_plus], axis=1)
bkk_espresso_ari
# Out:
#                          id                                   name        lat  \
# 0  4f2cf81ce4b006ef98a049e3  The Espresso Bar (ดิ เอสเพรสโซ่ บาร์)  13.783804
# 1  503c5a41e4b0f8bcbe90eb6c                   Bangkok Espresso Bar  13.780212
#
#           lng               address  price likes     rating
# 0  100.543540  19/3 Soi Ari 4 (Nua)  Cheap     3  no rating
# 1  100.544292      Phahon Yothin Rd  Cheap    23        7.4

# %% [markdown]
# We don't delete any of them, keeping in mind that Bangkok Espresso Bar has a good rating and a decent number of likes.

# %%
# add markers to map
for lat, lng, name, address in zip(bkk_espresso_ari['lat'], bkk_espresso_ari['lng'], bkk_espresso_ari['name'], bkk_espresso_ari['address']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#80bbff',
        fill=True,
        fill_color='#80bbff',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bangkok_ari)

# %% [markdown]
# The pizza place "Italian Job" and the coffee shop "Bangkok Espresso Bar" are very close to the Ari BTS Station.

# %%
coordinates = [
     [  13.782073,     100.543564],
     [  13.781635,     100.542700],
     [  13.780212,     100.544292]]

# Create the map and add the line
folium.PolyLine(coordinates, color='black').add_to(map_bangkok_ari)
# map_bangkok_ari.line(coordinates, line_color='#000000', line_weight=5)
map_bangkok_ari
 # m.create_map(path='line_example.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## <u>Thong Lo BTS Station</u>

# %%
# creating map of Bangkok using latitude and longitude values
latitude = 13.7384
longitude = 100.5663
map_bangkok_thonglo = folium.Map(location=[latitude, longitude], zoom_start=17)

folium.Marker(location=[latitude, longitude], icon=folium.Icon(color='orange', icon='train', prefix='fa')).add_to(map_bangkok_thonglo)
map_bangkok_thonglo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### PIZZA

# %%
# Searching for pizza places at not more than 500 mts from the Thong Lo BTS stop
LL = str(latitude) + ', ' + str(longitude)
RADIUS =500
CATEGORY_ID = '4bf58dd8d48988d1ca941735' # PIZZA PLACES CATEGORY ID
LIMIT = 50 # MAXIMUM VALUE
url = 'https://api.foursquare.com/v2/venues/search?ll={}&radius={}&categoryId={}&client_id={}&client_secret={}&v={}&limit={}'.format(
    LL,
    RADIUS,
    CATEGORY_ID,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    LIMIT
)

url
# Out:
# 'https://api.foursquare.com/v2/venues/search?ll=13.7384, 100.5663&radius=500&categoryId=4bf58dd8d48988d1ca941735&client_id=BTLFWZ1PUF4GT0J3F5H5KBNXS345DZDQRJ2CCXX0I251AUJH&client_secret=1W0MVZFCSKGFFCUA52GZ4OI3G0U2ZEY5TVUZYCZHJRYM3RJ2&v=20180605&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dfa482240a7ea001b844250'},
#  'response': {'venues': [{'id': '5ba9148407190200250e8805',
#     'name': 'BLEND BISTRO & WINE BAR',
#     'location': {'address': 'No84. Sukhumvit road soi 23',
#      'crossStreet': 'soi Prasanmitr',
#      'lat': 13.740156301379875,
#      'lng': 100.56393384933472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.740156301379875,
#        'lng': 100.56393384933472}],
#      'distance': 322,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'Bangkok',
#      'state': 'klong Toey Nuea Wattana',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['No84. Sukhumvit road soi 23 (soi Prasanmitr)',
#       'Bangkok',
#       'klong Toey Nuea Wattana 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683644',
#     'hasPerk': False},
#    {'id': '4db92f696a2334682da24e26',
#     'name': 'Pizza aroi',
#     'location': {'lat': 13.734974714548539,
#      'lng': 100.56365060721836,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.734974714548539,
#        'lng': 100.56365060721836}],
#      'distance': 476,
#      'cc': 'TH',
#      'city': 'Khlong Tan',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Khlong Tan', 'กรุงเทพมหานคร', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683644',
#     'hasPerk': False},
#    {'id': '556feccb498e5d30541d7633',
#     'name': 'Pizza House',
#     'location': {'address': 'Sukhumvit 21, Asok-Montri',
#      'lat': 13.740229606628418,
#      'lng': 100.56272888183594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.740229606628418,
#        'lng': 100.56272888183594}],
#      'distance': 436,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Sukhumvit 21, Asok-Montri',
#       'พระนคร',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683644',
#     'hasPerk': False},
#    {'id': '55fa6026498e077ee255df4e',
#     'name': 'Chef Yan Pizza',
#     'location': {'address': '39 Sukhumvit 23, Asok-Montri',
#      'crossStreet': 'Watthana',
#      'lat': 13.740129858434141,
#      'lng': 100.56317802270331,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.740129858434141,
#        'lng': 100.56317802270331}],
#      'distance': 388,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['39 Sukhumvit 23, Asok-Montri (Watthana)',
#       'พระนคร',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683644',
#     'hasPerk': False},
#    {'id': '4b6c0a76f964a520ee202ce3',
#     'name': 'Pizzeria Bella Napoli (พิซเซอเรีย เบลล่า นาโปลี)',
#     'location': {'address': '3/1 Sukhumvit 31',
#      'lat': 13.734331764574213,
#      'lng': 100.5663345766246,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.734331764574213,
#        'lng': 100.5663345766246}],
#      'distance': 452,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'วัฒนา',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['3/1 Sukhumvit 31',
#       'วัฒนา',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683644',
#     'hasPerk': False},
#    {'id': '4c2994959fb5d13a51669b57',
#     'name': 'Pizzeria da LUIGI',
#     'location': {'address': '2/A2-A4 Sukhumvit 25',
#      'lat': 13.735160473049211,
#      'lng': 100.56326394699275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.735160473049211,
#        'lng': 100.56326394699275}],
#      'distance': 487,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'วัฒนา',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['2/A2-A4 Sukhumvit 25',
#       'วัฒนา',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683644',
#     'hasPerk': False},
#    {'id': '537472e811d264146253ee50',
#     'name': 'Yan Pizza',
#     'location': {'lat': 13.740389112399322,
#      'lng': 100.56299668277762,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.740389112399322,
#        'lng': 100.56299668277762}],
#      'distance': 420,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683644',
#     'hasPerk': False}],
#   'confident': False}}

# %%
venues = results['response']['venues']
    
bkk_pizza_thonglo = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['id',
                    'name', 
                    'location.lat', 
                    'location.lng',
                    'location.address'
                   ]
bkk_pizza_thonglo = bkk_pizza_thonglo.loc[:, filtered_columns]

# clean columns
bkk_pizza_thonglo.columns = [col.split(".")[-1] for col in bkk_pizza_thonglo.columns]

bkk_pizza_thonglo
# Out:
#                          id                                              name  \
# 0  5ba9148407190200250e8805                           BLEND BISTRO & WINE BAR
# 1  4db92f696a2334682da24e26                                        Pizza aroi
# 2  556feccb498e5d30541d7633                                       Pizza House
# 3  55fa6026498e077ee255df4e                                    Chef Yan Pizza
# 4  4b6c0a76f964a520ee202ce3  Pizzeria Bella Napoli (พิซเซอเรีย เบลล่า นาโปลี)
# 5  4c2994959fb5d13a51669b57                                 Pizzeria da LUIGI
# 6  537472e811d264146253ee50                                         Yan Pizza
#
#          lat         lng                       address
# 0  13.740156  100.563934   No84. Sukhumvit road soi 23
# 1  13.734975  100.563651                           NaN
# 2  13.740230  100.562729     Sukhumvit 21, Asok-Montri
# 3  13.740130  100.563178  39 Sukhumvit 23, Asok-Montri
# 4  13.734332  100.566335              3/1 Sukhumvit 31
# 5  13.735160  100.563264          2/A2-A4 Sukhumvit 25
# 6  13.740389  100.562997                           NaN

# %%
# Pizza aroi (meaning good, tasty in thai), Chef Yan Pizza, Yan Pizza and Pizza House can be removed
# We are not sure about Blen Bistro, so we keep it
row_to_del = []
for i in range(len(bkk_pizza_thonglo)):
    if (bkk_pizza_thonglo.iloc[i,1].find('Pizza aroi') > -1):
        row_to_del.append(i)
    elif (bkk_pizza_thonglo.iloc[i,1].find('Pizza House') > -1):
        row_to_del.append(i)
    elif (bkk_pizza_thonglo.iloc[i,1].find('Yan') > -1):
        row_to_del.append(i)
bkk_pizza_thonglo = bkk_pizza_thonglo.drop(row_to_del, axis=0).reset_index().drop('index', axis=1)
bkk_pizza_thonglo
# Out:
#                          id                                              name  \
# 0  5ba9148407190200250e8805                           BLEND BISTRO & WINE BAR
# 1  4b6c0a76f964a520ee202ce3  Pizzeria Bella Napoli (พิซเซอเรีย เบลล่า นาโปลี)
# 2  4c2994959fb5d13a51669b57                                 Pizzeria da LUIGI
#
#          lat         lng                      address
# 0  13.740156  100.563934  No84. Sukhumvit road soi 23
# 1  13.734332  100.566335             3/1 Sukhumvit 31
# 2  13.735160  100.563264         2/A2-A4 Sukhumvit 25

# %%
# checking the price, number of likes and rating of the restaurants in our list
bkk_pizza_thonglo_plus = pd.DataFrame(index=[0,1,2], columns=['price', 'likes', 'rating'])
url = 'https://api.foursquare.com/v2/venues/'
for i in range(len(bkk_pizza_thonglo)):
    VENUE_ID = bkk_pizza_thonglo.iloc[i,0]
    params = dict(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        v=VERSION
    )
    results = requests.get(url=url+VENUE_ID, params=params)
    data = json.loads(results.text)
    try:
        bkk_pizza_thonglo_plus.iloc[i,0] = data['response']['venue']['price']['message']
    except:
        bkk_pizza_thonglo_plus.iloc[i,0] = "no price"
    try:
        bkk_pizza_thonglo_plus.iloc[i,1] = data['response']['venue']['likes']['count']
    except:
        bkk_pizza_thonglo_plus.iloc[i,1] = "no likes"
    try:
        bkk_pizza_thonglo_plus.iloc[i,2] = data['response']['venue']['rating']
    except:
        bkk_pizza_thonglo_plus.iloc[i,2] = "no rating"

# %%
bkk_pizza_thonglo = pd.concat([bkk_pizza_thonglo, bkk_pizza_thonglo_plus], axis=1)
bkk_pizza_thonglo
# Out:
#                          id                                              name  \
# 0  5ba9148407190200250e8805                           BLEND BISTRO & WINE BAR
# 1  4b6c0a76f964a520ee202ce3  Pizzeria Bella Napoli (พิซเซอเรีย เบลล่า นาโปลี)
# 2  4c2994959fb5d13a51669b57                                 Pizzeria da LUIGI
#
#          lat         lng                      address      price likes  \
# 0  13.740156  100.563934  No84. Sukhumvit road soi 23  Expensive     1
# 1  13.734332  100.566335             3/1 Sukhumvit 31  Expensive    99
# 2  13.735160  100.563264         2/A2-A4 Sukhumvit 25  Expensive    10
#
#       rating
# 0  no rating
# 1        7.7
# 2        6.6

# %% [markdown]
# Pizzeria Bella Napoli has the best rating and more likes.
# Anyway, we keep all three of them

# %%
# add markers to map
for lat, lng, name, address in zip(bkk_pizza_thonglo['lat'], bkk_pizza_thonglo['lng'], bkk_pizza_thonglo['name'], bkk_pizza_thonglo['address']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#ff0000',
        fill=True,
        fill_color='#f00f00',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bangkok_thonglo)

# %% [markdown]
# ### GELATO

# %%
# Searching for gelato places, with the word 'gelato' in their name
# at not more than 500 mts from the Thong Lo BTS stop
CATEGORY_ID = '4bf58dd8d48988d1c9941735' # ICE CREAM SHOP CATEGORY ID
QUERY = 'gelato'
url = 'https://api.foursquare.com/v2/venues/search?ll={}&query={}&radius={}&categoryId={}&client_id={}&client_secret={}&v={}&limit={}'.format(
    LL,
    QUERY,
    RADIUS,
    CATEGORY_ID,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?ll=13.7384, 100.5663&query=gelato&radius=500&categoryId=4bf58dd8d48988d1c9941735&client_id=BTLFWZ1PUF4GT0J3F5H5KBNXS345DZDQRJ2CCXX0I251AUJH&client_secret=1W0MVZFCSKGFFCUA52GZ4OI3G0U2ZEY5TVUZYCZHJRYM3RJ2&v=20180605&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dfa4877c94979001b8b8ec0'},
#  'response': {'venues': [{'id': '55057430498e3c2e1746c180',
#     'name': 'Gelato 44°C',
#     'location': {'address': 'Srinakharinwirot University',
#      'lat': 13.742689467950836,
#      'lng': 100.56470185505786,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.742689467950836,
#        'lng': 100.56470185505786}],
#      'distance': 507,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Srinakharinwirot University',
#       'พระนคร',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683646',
#     'hasPerk': False},
#    {'id': '5835cc9545005e0b8d83652b',
#     'name': 'Holey Gelato',
#     'location': {'address': '9/1 Sukhumvit Rd, Khwaeng Khlong Toei Nuea',
#      'lat': 13.73654511715722,
#      'lng': 100.56174248456955,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.73654511715722,
#        'lng': 100.56174248456955}],
#      'distance': 534,
#      'cc': 'TH',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['9/1 Sukhumvit Rd, Khwaeng Khlong Toei Nuea',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576683646',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
    
bkk_gelato_thonglo = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['id',
                    'name', 
                    'location.lat', 
                    'location.lng',
                    'location.address'
                   ]
bkk_gelato_thonglo = bkk_gelato_thonglo.loc[:, filtered_columns]

# clean columns
bkk_gelato_thonglo.columns = [col.split(".")[-1] for col in bkk_gelato_thonglo.columns]

bkk_gelato_thonglo
# Out:
#                          id          name        lat         lng  \
# 0  55057430498e3c2e1746c180   Gelato 44°C  13.742689  100.564702
# 1  5835cc9545005e0b8d83652b  Holey Gelato  13.736545  100.561742
#
#                                       address
# 0                 Srinakharinwirot University
# 1  9/1 Sukhumvit Rd, Khwaeng Khlong Toei Nuea

# %%
# checking the price, number of likes and rating of the ice-cream shops in our list
bkk_gelato_thonglo_plus = pd.DataFrame(index=list(bkk_gelato_thonglo.index), columns=['price', 'likes', 'rating'])
url = 'https://api.foursquare.com/v2/venues/'
for i in range(len(bkk_gelato_thonglo)):
    VENUE_ID = bkk_gelato_thonglo.iloc[i,0]
    params = dict(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        v=VERSION
    )
    results = requests.get(url=url+VENUE_ID, params=params)
    data = json.loads(results.text)
    try:
        bkk_gelato_thonglo_plus.iloc[i,0] = data['response']['venue']['price']['message']
    except:
        bkk_gelato_thonglo_plus.iloc[i,0] = "no price"
    try:
        bkk_gelato_thonglo_plus.iloc[i,1] = data['response']['venue']['likes']['count']
    except:
        bkk_gelato_thonglo_plus.iloc[i,1] = "no likes"
    try:
        bkk_gelato_thonglo_plus.iloc[i,2] = data['response']['venue']['rating']
    except:
        bkk_gelato_thonglo_plus.iloc[i,2] = "no rating"

# %%
bkk_gelato_thonglo = pd.concat([bkk_gelato_thonglo, bkk_gelato_thonglo_plus], axis=1)
bkk_gelato_thonglo
# Out:
#                          id          name        lat         lng  \
# 0  55057430498e3c2e1746c180   Gelato 44°C  13.742689  100.564702
# 1  5835cc9545005e0b8d83652b  Holey Gelato  13.736545  100.561742
#
#                                       address     price likes     rating
# 0                 Srinakharinwirot University  Moderate     3  no rating
# 1  9/1 Sukhumvit Rd, Khwaeng Khlong Toei Nuea  Moderate     3  no rating

# %% [markdown]
# Again, gelato shops have no rating. We keep them both.

# %%
# add markers to map
for lat, lng, name, address in zip(bkk_gelato_thonglo['lat'], bkk_gelato_thonglo['lng'], bkk_gelato_thonglo['name'], bkk_gelato_thonglo['address']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='magenta',
        fill=True,
        fill_color='magenta',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bangkok_thonglo)

# %% [markdown]
# ### ESPRESSO

# %%
# Searching for coffee shops, with the word espresso in their name,
# at not more than 500 mts from the Thong Lo BTS stop
CATEGORY_ID = '4bf58dd8d48988d1e0931735' # COFFEE SHOP CATEGORY ID
QUERY = 'espresso'
url = 'https://api.foursquare.com/v2/venues/search?ll={}&query={}&radius={}&categoryId={}&client_id={}&client_secret={}&v={}&limit={}'.format(
    LL,
    QUERY,
    RADIUS,
    CATEGORY_ID,
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?ll=13.7384, 100.5663&query=espresso&radius=500&categoryId=4bf58dd8d48988d1e0931735&client_id=BTLFWZ1PUF4GT0J3F5H5KBNXS345DZDQRJ2CCXX0I251AUJH&client_secret=1W0MVZFCSKGFFCUA52GZ4OI3G0U2ZEY5TVUZYCZHJRYM3RJ2&v=20180605&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dfa487a0de0d9001ba986db'},
#  'response': {'venues': []}}

# %% [markdown]
# There is no (explicitly named) espresso place at 500 mts from the BTS Skytrain in Thong Lo. Let's take a look of the whole map.

# %%
coordinates = [
     [  13.734332,     100.566335],
     [  13.736545,     100.561742]]

# Create the map and add the line
folium.PolyLine(coordinates, color='black').add_to(map_bangkok_thonglo)
map_bangkok_thonglo

# let's look at this map
map_bangkok_thonglo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Thong Lo seems to be a better choice, compared to Ari.
# First of all, there is no place explictly nominating 'espresso' in the close proximity of the BTS stop.
# Second, the most promising pizza place, Pizzeria Bella Napoli, is distant from the BTS stop and from the places for gelato.
# We miss the last piece of our analysis: let's analyze the Tripadvisor reviews of the best pizza restaurants in Thong Lo and Ari, according to the Foursquare ratings.

# %% [markdown]
# ## Tripadvisor Reviews

# %% [markdown]
# ### Bella Napoli - Thong Lo

# %%
# importing library
from bs4 import BeautifulSoup

URL_BASE = 'https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok.html'
MAX_PAGES = 30
counter = 0

for i in range(1, MAX_PAGES):
    if i > 1:
        url = "%spage/%d/" % (URL_BASE, i)
    else:
        url = URL_BASE
    req = requests.get(url)
    statusCode = req.status_code
    if statusCode == 200:
        html = BeautifulSoup(req.text, "html.parser")
        resultsoup = html.find_all('P', {'class': 'partial_entry'})
    else:
        break

for review in resultsoup:
    review_list = review.get_text()
    print(review_list)

# requesting data regarding Pizzeria Bella Napoli
url  = 'https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok.html'

# %%
def get_soup(url):
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:57.0) Gecko/20100101 Firefox/57.0'}
    r = s.get(url, headers=headers)
    if r.status_code != 200:
        print('status code:', r.status_code)
    else:
        return BeautifulSoup(r.text, 'html.parser')

def parse(url, response):
    if not response:
        print('no response:', url)
        return
    # get number of reviews
    num_reviews = response.find('span', class_='reviews_header_count').text
    num_reviews = num_reviews[1:-1] # remove `( )`
    num_reviews = num_reviews.replace(',', '') # remove `,`
    num_reviews = int(num_reviews)
    print('num_reviews:', num_reviews, type(num_reviews))
    
    # create template for urls to pages with reviews
    url = url.replace('.html', '-or{}.html')
    print('template:', url)

    # load pages with reviews
    for offset in range(0, num_reviews, 10):
        print('url:', url.format(offset))
        url_ = url.format(offset)
        parse_reviews(url_, get_soup(url_))

def parse_reviews(url, response):
    print('review:', url)
    if not response:
        print('no response:', url)
        return
    # get every review
    for idx, review in enumerate(response.find_all('div', class_='review-container')):
        item = {

            'restaurant_name': response.find('h1', class_='ui_header h1').text,
            'review_title': review.find('span', class_='noQuotes').text,
            'review_body': review.find('p', class_='partial_entry').text,
        }
        results.append(item) # <--- add to global list


# --- main ---
s = requests.Session()
start_url = 'https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok.html'
results = [] # <--- global list for items
parse(start_url, get_soup(url))

# convert list to DataFrame
df = pd.DataFrame(results)
# Out:
# num_reviews: 472 <class 'int'>
# template: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or{}.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or0.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or0.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or10.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or10.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or20.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or20.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or30.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or30.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or40.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or40.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or50.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or50.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or60.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or60.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or70.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or70.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or80.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or80.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or90.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or90.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or100.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or100.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or110.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or110.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or120.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or120.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or130.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or130.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or140.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or140.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or150.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or150.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or160.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or160.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or170.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or170.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or180.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or180.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or190.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or190.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or200.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or200.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or210.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or210.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or220.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or220.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or230.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or230.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or240.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or240.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or250.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or250.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or260.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or260.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or270.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or270.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or280.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or280.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or290.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or290.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or300.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or300.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or310.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or310.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or320.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or320.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or330.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or330.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or340.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or340.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or350.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or350.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or360.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or360.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or370.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or370.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or380.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or380.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or390.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or390.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or400.html
# review: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or400.html
# url: https://www.tripadvisor.com/Restaurant_Review-g293916-d792980-Reviews-Bella_Napoli-Bangkok-or410.html

# %%
df.head()

# %%
# importing WordCloud library
from wordcloud import WordCloud

# %%
text = " ".join(review for review in df['review_body'])
print ("There are {} words in the combination of all review.".format(len(text)))

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# %%
import matplotlib.pyplot as plt

# Display the generated image:
plt.figure(figsize = (20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# checking for reviews talking about their coffee
coffee_idxs = []
for i in range(len(df)):
    if 'coffee' in df.iloc[i,1]:
        coffee_idxs.append(df.iloc[i,1])
coffee_idxs

# %% [markdown]
# In 2 reviews, they talk about their coffee (probably an espresso) in a good way. They also offer Tiramisu, that even if it is not gelato, it's a potential substitute of it.

# %% [markdown]
# ## Basilico - Ari

# %%
URL_BASE = 'https://www.tripadvisor.com/Restaurant_Review-g293916-d3711564-Reviews-Basilico_Pizzeria-Bangkok.html'
MAX_PAGES = 30
counter = 0

for i in range(1, MAX_PAGES):
    if i > 1:
        url = "%spage/%d/" % (URL_BASE, i)
    else:
        url = URL_BASE
    req = requests.get(url)
    statusCode = req.status_code
    if statusCode == 200:
        html = BeautifulSoup(req.text, "html.parser")
        resultsoup = html.find_all('P', {'class': 'partial_entry'})
    else:
        break

for review in resultsoup:
    review_list = review.get_text()
    print(review_list)

# requesting data regarding Pizzeria Basilico
url  = 'https://www.tripadvisor.com/Restaurant_Review-g293916-d3711564-Reviews-Basilico_Pizzeria-Bangkok.html'

# %%
s = requests.Session()
start_url = 'https://www.tripadvisor.com/Restaurant_Review-g293916-d3711564-Reviews-Basilico_Pizzeria-Bangkok.html'
results = [] # <--- global list for items
parse(start_url, get_soup(url))

df = pd.DataFrame(results) # <--- convert list to DataFrame

# %%
df

# %%
text = " ".join(review for review in df['review_body'])
print ("There are {} words in the combination of all review.".format(len(text)))

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# %%
# Display the generated image:
plt.figure(figsize = (20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
